# %% [markdown]
# Each of the experiments had two evaluators: is_concise evaluator which was directly defined in our code and the correctness evaulator which we defined in the UI
#
# ![image.png](attachment:50bad59f-7b68-40d9-843b-4e02b02be6ec.png)
#
# We can also add filters to focus on some particular subsets of our experiments:
#
# ![image.png](attachment:3a3ff634-9630-4a1c-9023-888726bb13ac.png)
#
# Filtering our experiments based on the model "gpt-4o"
#
# ![image.png](attachment:ad2676de-abee-4b98-8790-528d9c0d87ab.png)
#
# First experiment that we ran:
#
# ![image.png](attachment:4c855a8e-2151-4686-af82-ba1fe44b5590.png)
#
# We can also jump from each of our experiments run to experiment trace:
#
# ![image.png](attachment:04fea7e8-8b29-49a4-ab40-9bfa8c2b1eb5.png)
#
# One of our evaluator run:
#
# ![image.png](attachment:00790578-e6d9-444f-a4c1-6fe8289141ff.png)
#
# Comparing two experiments:
#
# ![image.png](attachment:97adc613-b633-40e7-9249-bdc63a2b0b48.png)
#
# Summary charts for these two experiments:
#
# ![image.png](attachment:c8e3680b-4c71-4dbd-a785-abef0b464ed7.png)
#
# Data charts on latency:
#
# ![image.png](attachment:3ece9d09-fb89-4be7-b58c-f841e1e140cd.png)
