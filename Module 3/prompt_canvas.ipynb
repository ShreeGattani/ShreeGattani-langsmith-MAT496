# %% [markdown]
# # Prompt canvas interface in Langsmith
#
# ![image.png](attachment:8ddf4942-3603-41dc-8af6-49f90414cdfc.png)
#
#  Using the new version of our promt which we have provided
#
# ![image.png](attachment:50b8f201-9bf5-4a15-83d5-910b76a9667a.png)
#
#  Updating the new version of our prompt=
#
# ![image.png](attachment:d92d9fa5-9ad2-4658-9ca4-db2f9f9b6473.png)
#
#  Chatting with the the pirate persona model
#
# ![image.png](attachment:b93b4b81-e4a7-40f2-b51b-3ed739b3d0d0.png)
#
#  for changing the specific parts of the given prompt
#
# ![image.png](attachment:3dd6adc6-a8a7-448b-86c9-8ad09f23a8ef.png)
